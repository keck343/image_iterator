# %%
import pandas as pd
import numpy as np
from IPython.display import Image

# %%
# always_recycle_art/composites/ # 3728 composites
# always_recycle_art/cropped_inputs/ # 57 images, 3 versions each
# existential_day_100/composites/labels.csv

labels_df = pd.read_csv("existential_day_100/composites/labels.csv")
labels_df.head()
# Out:
#    Unnamed: 0                                             image  \
# 0           0  existential_day_100/composites/composite_215.jpg
# 1           1  existential_day_100/composites/composite_201.jpg
# 2           2   existential_day_100/composites/composite_26.jpg
# 3           3   existential_day_100/composites/composite_32.jpg
# 4           4  existential_day_100/composites/composite_188.jpg
#
#                                  label  percentage
# 0                 sea anemone, anemone   15.625580
# 1                           safety pin   44.522686
# 2  handkerchief, hankie, hanky, hankey   26.242722
# 3             spider web, spider's web   21.648129
# 4                        jigsaw puzzle   28.188601

# %%
labels_df = pd.read_csv("existential_day_100/composites/labels.csv")
labels_df["label"] = [x.split(",")[0] for x in labels_df["label"]]

for l in sorted(labels_df.label.unique()):
    print(l)
# Out:
# analog clock
# apron
# book jacket
# bubble
# coho
# coral reef
# guillotine
# handkerchief
# honeycomb
# jellyfish
# jigsaw puzzle
# maze
# mosquito net
# nematode
# paintbrush
# pillow
# poncho
# quilt
# rock python
# safety pin
# sea anemone
# shower curtain
# spider web
# squirrel monkey
# stingray
# stole
# sundial
# tray
# umbrella
# wall clock
# water snake
# wreck

# %%
labels_df[labels_df.label == "wreck"]
# Out:
#      Unnamed: 0                                             image  label  \
# 119         119  existential_day_100/composites/composite_109.jpg  wreck
# 186         186   existential_day_100/composites/composite_39.jpg  wreck
# 189         189   existential_day_100/composites/composite_15.jpg  wreck
# 200         200  existential_day_100/composites/composite_186.jpg  wreck
#
#      percentage
# 119   26.511700
# 186   15.380889
# 189   22.756485
# 200   13.570417

# %%
labels_df.groupby("label").count().reset_index().sort_values(['image'], ascending=False)[["label", "image"]]
# Out:
#                label  image
# 6       handkerchief    529
# 13      mosquito net    290
# 18             quilt    280
# 24        spider web     80
# 9      jigsaw puzzle     49
# 7          honeycomb     43
# 23    shower curtain     42
# 17            pillow     41
# 1        book jacket     33
# 15        paintbrush     31
# 16         parachute     28
# 27          stingray     27
# 33        wall clock     26
# 31              tray     26
# 28             stole     20
# 14          nematode     19
# 35             wreck     16
# 12              maze     15
# 21         sea snake     14
# 32          umbrella      8
# 29           sundial      8
# 11  magnetic compass      7
# 5           envelope      7
# 34       water snake      5
# 30   swimming trunks      4
# 20       sea anemone      4
# 19   radio telescope      3
# 22        shower cap      3
# 2             bubble      3
# 3               coho      1
# 26   squirrel monkey      1
# 4         coral reef      1
# ...

# %%
labels_df = pd.read_csv("existential_day_103/composites/labels.csv")
labels_df["label"] = [x.split(",")[0] for x in labels_df["label"]]

for l in sorted(labels_df.label.unique()):
    print(l)
# Out:
# analog clock
# book jacket
# bubble
# coho
# coral reef
# envelope
# handkerchief
# honeycomb
# jellyfish
# jigsaw puzzle
# junco
# magnetic compass
# maze
# mosquito net
# nematode
# paintbrush
# parachute
# pillow
# quilt
# radio telescope
# sea anemone
# sea snake
# shower cap
# shower curtain
# spider web
# spindle
# squirrel monkey
# stingray
# stole
# sundial
# swimming trunks
# tray
# umbrella
# wall clock
# water snake
# wreck

# %%
labels_df[labels_df.label == "wreck"]
# Out:
#       Unnamed: 0                                              image  label  \
# 25            25  existential_day_103/composites/composite_1350.jpg  wreck
# 26            26   existential_day_103/composites/composite_981.jpg  wreck
# 70            70   existential_day_103/composites/composite_837.jpg  wreck
# 128          128  existential_day_103/composites/composite_1353.jpg  wreck
# 341          341   existential_day_103/composites/composite_984.jpg  wreck
# 427          427  existential_day_103/composites/composite_1125.jpg  wreck
# 432          432   existential_day_103/composites/composite_909.jpg  wreck
# 502          502   existential_day_103/composites/composite_840.jpg  wreck
# 561          561  existential_day_103/composites/composite_1278.jpg  wreck
# 583          583  existential_day_103/composites/composite_1053.jpg  wreck
# 690          690  existential_day_103/composites/composite_1056.jpg  wreck
# ...

# %%
labels_df.groupby("label").count().reset_index().sort_values(['image'], ascending=False)
# Out:
#                label  Unnamed: 0  image  percentage
# 6       handkerchief         529    529         529
# 13      mosquito net         290    290         290
# 18             quilt         280    280         280
# 24        spider web          80     80          80
# 9      jigsaw puzzle          49     49          49
# 7          honeycomb          43     43          43
# 23    shower curtain          42     42          42
# 17            pillow          41     41          41
# 1        book jacket          33     33          33
# 15        paintbrush          31     31          31
# 16         parachute          28     28          28
# 27          stingray          27     27          27
# 33        wall clock          26     26          26
# 31              tray          26     26          26
# 28             stole          20     20          20
# 14          nematode          19     19          19
# 35             wreck          16     16          16
# ...

# %%
labels_df = pd.read_csv("existential_day_103/cropped_inputs/labels.csv")
labels_df["label"] = [x.split(",")[0] for x in labels_df["label"]]

for l in sorted(labels_df.label.unique()):
    print(l)
# Out:
# brassiere
# comic book
# coral reef
# handkerchief
# honeycomb
# jellyfish
# lampshade
# nematode
# paintbrush
# pillow
# scuba diver
# shower curtain
# spider web
# tray

# %%
labels_df.groupby("label").count().reset_index().sort_values(['image'], ascending=False)
# Out:
#              label  Unnamed: 0  image  percentage
# 3     handkerchief           7      7           7
# 5        jellyfish           3      3           3
# 12      spider web           3      3           3
# 2       coral reef           2      2           2
# 7         nematode           2      2           2
# 9           pillow           2      2           2
# 0        brassiere           1      1           1
# 1       comic book           1      1           1
# 4        honeycomb           1      1           1
# 6        lampshade           1      1           1
# 8       paintbrush           1      1           1
# 10     scuba diver           1      1           1
# 11  shower curtain           1      1           1
# 13            tray           1      1           1

# %%
labels_df = pd.read_csv("always_recycle_art/cropped_inputs/labels.csv")
labels_df["label"] = [x.split(",")[0] for x in labels_df["label"]]

for l in sorted(labels_df.label.unique()):
    print(l)
# Out:
# Band Aid
# Christmas stocking
# Windsor tie
# backpack
# balance beam
# balloon
# book jacket
# car mirror
# comic book
# computer keyboard
# conch
# consomme
# dial telephone
# doormat
# drumstick
# electric fan
# envelope
# fire screen
# fountain
# goldfish
# hammerhead
# hand blower
# handkerchief
# harp
# honeycomb
# jack-o'-lantern
# jellyfish
# jigsaw puzzle
# killer whale
# king penguin
# kite
# loupe
# manhole cover
# matchstick
# maze
# megalith
# mosquito net
# mouse
# nematode
# orange
# paddlewheel
# parachute
# pillow
# ping-pong ball
# plastic bag
# platypus
# poncho
# prison
# puck
# quilt
# radiator
# radio telescope
# rock beauty
# rubber eraser
# rule
# sarong
# slug
# spider web
# spotlight
# stingray
# stole
# stove
# strainer
# switch
# tennis ball
# toilet tissue
# toucan
# tray
# velvet
# wall clock
# wallet
# water snake
# window screen
# wool
# wreck

# %%
labels_df.sort_values("image")[["image", "label", "percentage"]] # .sort_values(['percentage'], ascending=False)  # different crops get different labels
# Out:
#                                                 image              label  \
# 118   always_recycle_art/cropped_inputs/crop_0_v1.jpg               wool
# 108   always_recycle_art/cropped_inputs/crop_0_v2.jpg        paddlewheel
# 113   always_recycle_art/cropped_inputs/crop_0_v3.jpg               wool
# 148  always_recycle_art/cropped_inputs/crop_10_v1.jpg         wall clock
# 135  always_recycle_art/cropped_inputs/crop_10_v2.jpg        book jacket
# 128  always_recycle_art/cropped_inputs/crop_10_v3.jpg       handkerchief
# 39   always_recycle_art/cropped_inputs/crop_11_v1.jpg           envelope
# 50   always_recycle_art/cropped_inputs/crop_11_v2.jpg           envelope
# 63   always_recycle_art/cropped_inputs/crop_11_v3.jpg            doormat
# 156  always_recycle_art/cropped_inputs/crop_12_v1.jpg             wallet
# 168  always_recycle_art/cropped_inputs/crop_12_v2.jpg             poncho
# 159  always_recycle_art/cropped_inputs/crop_12_v3.jpg           envelope
# ...

# %%
labels_df[labels_df.label == "wreck"]
# Out:
#     Unnamed: 0                                             image  label  \
# 72          72  always_recycle_art/cropped_inputs/crop_46_v3.jpg  wreck
#
#     percentage
# 72   62.718616

# %%
labels_df.groupby("label").count().reset_index().sort_values(['image'], ascending=False)
# Out:
#                  label  Unnamed: 0  image  percentage
# 16            envelope          15     15          15
# 22        handkerchief          13     13          13
# 68              velvet          12     12          12
# 6          book jacket          10     10          10
# 67                tray          10     10          10
# 57          spider web           6      6           6
# 27       jigsaw puzzle           5      5           5
# 19            goldfish           5      5           5
# 43      ping-pong ball           4      4           4
# 38            nematode           4      4           4
# 34                maze           4      4           4
# 5              balloon           3      3           3
# 28        killer whale           3      3           3
# 25     jack-o'-lantern           3      3           3
# 13             doormat           3      3           3
# 73                wool           3      3           3
# ...
